# %% [markdown]
# # Explore here

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from dotenv import load_dotenv

# load the .env file variables
load_dotenv()
# Out:
# True

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# Define your credentials (replace with your actual values)
client_id = "e246c06be2ef4d96b0a7c89b9e2a8189"
client_secret = "90d70000d68e41188c47a17af29e703e"

# Authenticate
auth_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
spotify = spotipy.Spotify(auth_manager=auth_manager)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

auth_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
spotify = spotipy.Spotify(auth_manager=auth_manager)

# %%
artist_id = "3TVXtAsR1Inumwj472S9r4"  # Drake
results = spotify.artist_top_tracks(artist_id)

for track in results['tracks']:
    print(track['name'])
# Out:
# One Dance
# Headlines
# Passionfruit
# Not You Too (feat. Chris Brown)
# NOKIA
# God's Plan
# WAIT FOR U (feat. Drake & Tems)
# She Will
# DIE TRYING
# Hotline Bling

# %%
from spotipy.oauth2 import SpotifyClientCredentials

auth_manager = SpotifyClientCredentials(
    client_id="e246c06be2ef4d96b0a7c89b9e2a8189",
    client_secret="90d70000d68e41188c47a17af29e703e"
)

# %%
import spotipy
artist_id = "3TVXtAsR1Inumwj472S9r4"

# Get the top tracks of an artist
results = spotify.artist_top_tracks(artist_id)

songs = []
for track in results['tracks']:
    songs.append({
        'name': track['name'],
        'popularity': track['popularity'],
        'duration_min': track['duration_ms'] / 60000
    })

# %%
tracks_df = pd.DataFrame(songs)

print(tracks_df.head(3))
# Out:
#            name  popularity  duration_min
# 0     One Dance          91      2.899767
# 1     Headlines          87      3.933100
# 2  Passionfruit          87      4.982333

# %%
import pandas as pd

# Example: creating a DataFrame manually
data = {
    "duration_min": [3.5, 4.2, 2.8, 5.0],
    "popularity": [85, 90, 70, 60]
}
df = pd.DataFrame(data)

# Now plotting works
import matplotlib.pyplot as plt

plt.scatter(df['duration_min'], df['popularity'])
plt.xlabel('Duration (minutes)')
plt.ylabel('Popularity')
plt.title('Relationship between duration and popularity')
plt.show()
